# %%
import pandas as pd
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
import nltk

# %%
# Download NLTK data (only need to run once)
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Amol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Amol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Amol\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def clean_job_description(text):
    # Step 1: Lowercasing
    text = text.lower()
    # Step 2: Remove HTML Tags
    text = BeautifulSoup(text, "html.parser").get_text()
    # Step 3: Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

    def replace_range_with_average(match):
        num1, num2 = map(int, match.group().split('-'))
        return str((num1 + num2) // 2)
    text = re.sub(r'\b\d+-\d+\b', replace_range_with_average, text)

    # Step 4: Remove Non-Alphanumeric Characters
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)    
    # Step 5: Tokenization
    tokens = word_tokenize(text)
    # Step 6: Remove Stop Words
    stop_words = set(stopwords.words('english'))
    custom_stop_words = {"details", "visit", "looking", "we", "are", "must", "have"}
    stop_words.update(custom_stop_words)
    tokens = [word for word in tokens if word not in stop_words]
    # Step 8: Join Tokens
    cleaned_text = ' '.join(tokens)
    # Step 9: Capitalize First Letter of Each Word
    capitalized_text = cleaned_text.title()
    return capitalized_text

# %%
df = pd.read_csv(r'.\data\job_data.csv')
df['Processed Job Description'] = df['Description'].apply(clean_job_description)
df.head()
# Out:
#                    Title                                        Description  \
# 0    Fullstack Developer  Introduction\n\nAt IBM, work is more than a jo...
# 1  Remote Data Scientist  A leading US client is seeking Data Scientists...
# 2    AWS DevOps Engineer  Job Title: Sr. AWS DevOps Engineer\n Job Locat...
# 3         Data Scientist  ABOUT THE POSITION:\n\nThis position will be w...
# 4     Data Scientist III  Intuit Credit Karma is a mission-driven compan...
#
#                                        Detail URL  \
# 0  https://www.linkedin.com/jobs/view/4025815970/
# 1  https://www.linkedin.com/jobs/view/4040359115/
# 2  https://www.linkedin.com/jobs/view/4057613660/
# 3  https://www.linkedin.com/jobs/view/4054420394/
# 4  https://www.linkedin.com/jobs/view/4019123395/
#
#                            Location  \
# 0  Bengaluru East, Karnataka, India
# 1                             India
# 2       Bengaluru, Karnataka, India
# 3       Bengaluru, Karnataka, India
# 4       Bengaluru, Karnataka, India
#
#                                  Company Name  \
# 0                                         IBM
# 1                                      Turing
# 2  Centilytics | Intelligent Cloud Management
# 3                                     Fluence
# 4                                Credit Karma
#
#                                         Company Logo  \
# 0  https://media.licdn.com/dms/image/v2/D560BAQGi...
# 1  https://media.licdn.com/dms/image/v2/D4D0BAQFw...
# 2  https://media.licdn.com/dms/image/v2/C510BAQFW...
# 3  https://media.licdn.com/dms/image/v2/D4E0BAQFX...
# 4  https://media.licdn.com/dms/image/v2/D560BAQHE...
#
#                                    Company Apply Url  \
# 0  https://IBM.contacthr.com/142516460?Codes=SN_L...
# 1  https://www.turing.com/remote-developer-jobs/j...
# 2      https://www.linkedin.com/job-apply/4057613660
# 3  https://jobs.lever.co/fluence/58068d9c-5e16-49...
# 4      https://www.linkedin.com/job-apply/4019123395
#
#                            Processed Job Description  Required Experience  \
# 0  Introduction Ibm Work Job Calling Build Design...                  8.0
# 1  Leading Us Client Seeking Data Scientists Data...                  2.0
# 2  Job Title Sr Aws Devops Engineer Job Location ...                  7.5
# 3  Position Position Within Fluence Data Science ...                  5.0
# 4  Intuit Credit Karma Mission Driven Company Foc...                  7.0
#
#                                               skills
# 0  Typescript Api Java Javascript Ai Rest Css Nos...
# 1                             Python Sql Engineering
# 2   Scripting Shell Azure Python Mysql Aws Cloud Git
# 3       Pandas Engineering Python Cloud Sql Numpy Ai
# 4            Engineering Python Tensorflow Cloud Sql

# %%
def average_work_experience(job_description):  
    pattern = re.compile(r'''  
        (?<!\d)  
        (?:(\d)\s*(?:-\s*|\s*to\s*)(\d)\s*years?| 
        (\d)\s*years?|   
        (?:minimum|at least)\s*(\d)\s*years?|    
        (\d)\s*[^-]*?(?:experience|exp|needed|required|or|and)?)(?!\d)
    ''', re.VERBOSE | re.IGNORECASE)  

    matches = pattern.findall(job_description)  
    years = []  

    for match in matches:  
        # Collect years from the captures  
        if match[0] and match[1]: 
            low_exp = int(match[0])  
            high_exp = int(match[1])   
            if low_exp < 10 and high_exp < 10:    
                years.append((low_exp + high_exp) / 2) 
        elif match[2]:   
            years.append(int(match[2]))   
        elif match[3]:   
            years.append(int(match[3]))   
        elif match[4]:   
            years.append(int(match[4])) 
    
    if years:  
        max_year = max(years)
        return max_year
    return 0

# %%
df['Required Experience'] = df['Description'].apply(average_work_experience)
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
df.head()
# Out:
#                             Title  \
# 0        Applications Developer 3
# 1  C++ Software Engineer - Gaming
# 2       Application Engineer - II
# 3                 Data Scientists
# 4        Software Engineer I, ITC
#
#                                          Description  \
# 0  Job Description\n\nAnalyze, design develop, tr...
# 1  Description\n\nThe Team and Role\n\nThe Gaming...
# 2  Role Description\n\nFlipkart is shaping the e-...
# 3  AI Engineer: Design and implement generative A...
# 4  Become a Part of the NIKE, Inc. Team\n\nNIKE, ...
#
#                                        Detail URL  \
# 0  https://www.linkedin.com/jobs/view/4074922230/
# 1  https://www.linkedin.com/jobs/view/4075387645/
# 2  https://www.linkedin.com/jobs/view/3927701360/
# 3  https://www.linkedin.com/jobs/view/4042203122/
# 4  https://www.linkedin.com/jobs/view/4076648322/
#
#                             Location Company Name  \
# 0        Bengaluru, Karnataka, India       Oracle
# 1         Chennai, Tamil Nadu, India     Logitech
# 2        Bengaluru, Karnataka, India     Flipkart
# 3  Bangalore Urban, Karnataka, India      Virtusa
# 4                   Karnataka, India         Nike
#
#                                         Company Logo  \
# 0  https://media.licdn.com/dms/image/v2/D4E0BAQHY...
# 1  https://media.licdn.com/dms/image/v2/D560BAQGZ...
# 2  https://media.licdn.com/dms/image/v2/C560BAQF6...
# 3  https://media.licdn.com/dms/image/v2/D560BAQGE...
# 4  https://media.licdn.com/dms/image/v2/C560BAQFc...
#
#                                    Company Apply Url  \
# 0  https://eeho.fa.us2.oraclecloud.com/hcmUI/Cand...
# 1  https://jobs.jobvite.com/logitech/job/ob9Oufwm...
# 2  http://www.flipkartcareers.com/#!/job-view/app...
# 3  https://www.virtusa.com/careers/in/bangalore/a...
# 4  https://click.appcast.io/track/l4rehql-org?cs=...
#
#                            Processed Job Description  Required Experience  \
# 0  Job Description Analyze Design Develop Trouble...                  6.0
# 1  Description Team Role Gaming Brand Logitech G ...                  7.0
# 2  Role Description Flipkart Shaping E Commerce E...                  4.5
# 3  Ai Engineer Design Implement Generative Ai Mod...                  0.0
# 4  Become Part Nike Inc Team Nike Inc Outfit Worl...                  1.0
#
#                                               skills
# 0                                Java Saas Git Cloud
# 1                                 C++ Python C React
# 2  Scripting Engineering Java Javascript Python L...
# 3  Keras Pytorch Api Java Azure Python Opencv Ten...
# 4  Engineering Javascript Python Nosql React Clou...

# %%
df.to_csv(r'.\data\job_data.csv', index=False, header=True)

# %%
def get_unique_skills(s):
    df = pd.read_csv(r'.\data\job_data.csv')
    # Filter rows where title contains 'data scientist' (case insensitive)
    filtered_df = df[df['Title'].str.contains(s, case=False)]

    # Extract skills from the filtered rows and split into individual skills
    skills = filtered_df['skills'].str.split().explode()

    # Get unique skills
    unique_skills = skills.unique()

    # Print the unique skills
    print(f"Unique skills for jobs with {s} in the title:")
    print(unique_skills)
    
get_unique_skills('Engineer')
# Out:
# Unique skills for jobs with Engineer in the title:
# ['C++' 'Python' 'C' 'React' 'Scripting' 'Engineering' 'Java' 'Javascript'
#  'Linux' 'Nosql' 'Cloud' 'Aws' 'Git' 'Azure' 'Postgres' 'Mysql' 'Rest'
#  'Ai' 'Html' 'Css' 'Coding' 'Postgresql' 'Sql' 'Mongodb' 'Api'
#  'Typescript' 'Shell' 'Saas']
